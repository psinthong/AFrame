# %%
from aframe import AFrame
import pandas as pd

# %%
af = AFrame(dataverse='test', dataset='TweetItems')

# %%
af
# Out:
# AsterixDB DataFrame with the following known columns:
# 	[{'name': 'row_id', 'type': 'int32', 'nullable': False}]

# %%
len(af)
# Out:
# 5981

# %%
af.columns
# Out:
# "[{'name': 'row_id', 'type': 'int32', 'nullable': False}]"

# %%
df = af.toPandas()

# %%
df.head()
# Out:
#         contributors coordinates          created_at display_text_range  \
# row_id
# 0                NaN        None 2018-02-08 05:18:41                NaN
# 1                NaN        None 2018-02-08 05:18:41                NaN
# 2                NaN        None 2018-02-08 05:18:41           [0, 140]
# 3                NaN        None 2018-02-08 05:18:41          [17, 140]
# 4                NaN        None 2018-02-08 05:18:41                NaN
#
#                                                  entities  \
# row_id
# 0       {'hashtags': [], 'urls': [], 'user_mentions': ...
# 1       {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2       {'hashtags': [{'text': 'POTUS', 'indices': [66...
# 3       {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 4       {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                         extended_entities  \
# row_id
# 0       {'media': [{'id': 961400756740923392, 'id_str'...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
#                                            extended_tweet  favorite_count  \
# row_id
# 0                                                     NaN               0
# 1                                                     NaN               0
# 2       {'full_text': 'CNN - INTERNATIONAL . THE LEAST...               0
# 3       {'full_text': '@realDonaldTrump The Russian As...               0
# 4                                                     NaN               0
#
#         favorited filter_level          ...          retweet_count  retweeted  \
# row_id                                  ...
# 0           False          low          ...                      0      False
# 1           False          low          ...                      0      False
# 2           False          low          ...                      0      False
# 3           False          low          ...                      0      False
# 4           False          low          ...                      0      False
#
#                                          retweeted_status  \
# row_id
# 0       {'created_at': 'Thu Feb 08 00:46:19 +0000 2018...
# 1       {'created_at': 'Wed Feb 07 22:54:04 +0000 2018...
# 2                                                     NaN
# 3                                                     NaN
# 4       {'created_at': 'Wed Feb 07 15:48:03 +0000 2018...
#
#                                                    source  \
# row_id
# 0       <a href="http://twitter.com" rel="nofollow">Tw...
# 1       <a href="http://twitter.com/download/iphone" r...
# 2       <a href="http://twitter.com" rel="nofollow">Tw...
# 3       <a href="http://twitter.com/download/android" ...
# 4       <a href="http://twitter.com/download/iphone" r...
#
#                                                      text  \
# row_id
# 0       RT @MicahGrimes: 2 iconic photos. 1 year. Only...
# 1       RT @EdKrassen: Nancy Pelosi has more Enerygy a...
# 2       CNN - INTERNATIONAL . THE LEAST  TRUSTED  NAME...
# 3       @realDonaldTrump The Russian Asset Donald Trum...
# 4       RT @nowthisnews: This Trump supporter used the...
#
#                   timestamp_ms  truncated  \
# row_id
# 0      2018-02-08 05:18:41.604      False
# 1      2018-02-08 05:18:41.705      False
# 2      2018-02-08 05:18:41.713       True
# 3      2018-02-08 05:18:41.773       True
# 4      2018-02-08 05:18:41.802      False
#
#                                                      user  \
# row_id
# 0       {'id': 320000200, 'id_str': '320000200', 'name...
# 1       {'id': 50667682, 'id_str': '50667682', 'name':...
# 2       {'id': 882677034429710336, 'id_str': '88267703...
# 3       {'id': 958747420904497153, 'id_str': '95874742...
# 4       {'id': 749752742, 'id_str': '749752742', 'name...
#
#                                         uuid withheld_in_countries
# row_id
# 0       5517ec1b-34f9-1e47-36bd-f78b48e6743a                   NaN
# 1       5517ec1b-34f9-1e47-36bd-f78b48e6743d                   NaN
# 2       5517ec1b-34f9-1e47-36bd-f78b48e6743b                   NaN
# 3       5517ec1b-34f9-1e47-36bd-f78b48e6743c                   NaN
# 4       5517ec1b-34f9-1e47-36bd-f78b48e6743e                   NaN
#
# [5 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'extended_tweet', 'favorite_count',
#        'favorited', 'filter_level', 'geo', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'possibly_sensitive', 'quote_count', 'quoted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'reply_count',
#        'retweet_count', 'retweeted', 'retweeted_status', 'source', 'text',
#        'timestamp_ms', 'truncated', 'user', 'uuid', 'withheld_in_countries'],
#       dtype='object')

# %%
af['truncated'].head(2)
# Out:
#         truncated
# row_id
# 0           False
# 1           False

# %%
df['truncated'].head(2)
# Out:
# row_id
# 0    False
# 1    False
# Name: truncated, dtype: bool

# %%
af[af['truncated'] == True].head(2)
# Out:
#         contributors  coordinates          created_at display_text_range  \
# row_id
# 2                NaN          NaN 2018-02-08 05:18:41           [0, 140]
# 3                NaN          NaN 2018-02-08 05:18:41          [17, 140]
#
#                                                  entities  \
# row_id
# 2       {'hashtags': [{'text': 'POTUS', 'indices': [66...
# 3       {'hashtags': [], 'urls': [{'url': 'https://t.c...
#
#                                            extended_tweet  favorite_count  \
# row_id
# 2       {'full_text': 'CNN - INTERNATIONAL . THE LEAST...               0
# 3       {'full_text': '@realDonaldTrump The Russian As...               0
#
#         favorited filter_level  geo                  ...                   \
# row_id                                               ...
# 2           False          low  NaN                  ...
# 3           False          low  NaN                  ...
#
#         quoted_status_id_str  reply_count retweet_count  retweeted  \
# row_id
# 2               9.561978e+17            0             0      False
# 3                        NaN            0             0      False
#
#                                                    source  \
# row_id
# 2       <a href="http://twitter.com" rel="nofollow">Tw...
# 3       <a href="http://twitter.com/download/android" ...
#
#                                                      text  \
# row_id
# 2       CNN - INTERNATIONAL . THE LEAST  TRUSTED  NAME...
# 3       @realDonaldTrump The Russian Asset Donald Trum...
#
#                   timestamp_ms  truncated  \
# row_id
# 2      2018-02-08 05:18:41.713       True
# 3      2018-02-08 05:18:41.773       True
#
#                                                      user  \
# row_id
# 2       {'id': 882677034429710336, 'id_str': '88267703...
# 3       {'id': 958747420904497153, 'id_str': '95874742...
#
#                                         uuid
# row_id
# 2       5517ec1b-34f9-1e47-36bd-f78b48e6743b
# 3       5517ec1b-34f9-1e47-36bd-f78b48e6743c
#
# [2 rows x 34 columns]

# %%
df[df['truncated'] == True].head(2)
# Out:
#         contributors coordinates          created_at display_text_range  \
# row_id
# 2                NaN        None 2018-02-08 05:18:41           [0, 140]
# 3                NaN        None 2018-02-08 05:18:41          [17, 140]
#
#                                                  entities extended_entities  \
# row_id
# 2       {'hashtags': [{'text': 'POTUS', 'indices': [66...               NaN
# 3       {'hashtags': [], 'urls': [{'url': 'https://t.c...               NaN
#
#                                            extended_tweet  favorite_count  \
# row_id
# 2       {'full_text': 'CNN - INTERNATIONAL . THE LEAST...               0
# 3       {'full_text': '@realDonaldTrump The Russian As...               0
#
#         favorited filter_level          ...          retweet_count  retweeted  \
# row_id                                  ...
# 2           False          low          ...                      0      False
# 3           False          low          ...                      0      False
#
#         retweeted_status                                             source  \
# row_id
# 2                    NaN  <a href="http://twitter.com" rel="nofollow">Tw...
# 3                    NaN  <a href="http://twitter.com/download/android" ...
#
#                                                      text  \
# row_id
# 2       CNN - INTERNATIONAL . THE LEAST  TRUSTED  NAME...
# 3       @realDonaldTrump The Russian Asset Donald Trum...
#
#                   timestamp_ms  truncated  \
# row_id
# 2      2018-02-08 05:18:41.713       True
# 3      2018-02-08 05:18:41.773       True
#
#                                                      user  \
# row_id
# 2       {'id': 882677034429710336, 'id_str': '88267703...
# 3       {'id': 958747420904497153, 'id_str': '95874742...
#
#                                         uuid withheld_in_countries
# row_id
# 2       5517ec1b-34f9-1e47-36bd-f78b48e6743b                   NaN
# 3       5517ec1b-34f9-1e47-36bd-f78b48e6743c                   NaN
#
# [2 rows x 37 columns]

# %%
a = af['truncated']
print(a.query)
# Out:
# from test.TweetItems_c t select t.row_id, t.data.truncated;

# %%
a = af['truncated'] == True
print(a.query)
# Out:
# with q as(from test.TweetItems_c t select t.row_id, t.data.truncated) from q t select t.row_id, t.truncated=True truncated;

# %%
a = af[af['truncated'] == True]
print(a.query)
# Out:
# with q as(with q as(from test.TweetItems_c t select t.row_id, t.data.truncated) from q t select t.row_id, t.truncated=True truncated)
# from q t1 LEFT OUTER JOIN test.TweetItems_c t on t.row_id=t1.row_id where t1.truncated select value t;

# %%
a = (af['truncated'] == True) & (af['favorited'] == False)
print(a.query)
# Out:
# with q1 as (with q as(from test.TweetItems_c t select t.row_id, t.data.truncated) from q t select t.row_id, t.truncated=True truncated),
#   q2 as(with q as(from test.TweetItems_c t select t.row_id, t.data.favorited) from q t select t.row_id, t.favorited=False favorited)
#  from q1 t, q2 t2 where t.row_id=t2.row_id select t.row_id, t.truncated and t2.favorited as result;

# %%
a.head()
# Out:
#         result
# row_id
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False

# %%
b = (df['truncated'] == True) & (df['favorited'] == False)
b.head()
# Out:
# row_id
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
a = af[(af['truncated'] == True) & (af['favorited'] == False)]
print(a.query)
# Out:
# with q as(with q1 as (with q as(from test.TweetItems_c t select t.row_id, t.data.truncated) from q t select t.row_id, t.truncated=True truncated),
#   q2 as(with q as(from test.TweetItems_c t select t.row_id, t.data.favorited) from q t select t.row_id, t.favorited=False favorited)
#  from q1 t, q2 t2 where t.row_id=t2.row_id select t.row_id, t.truncated and t2.favorited as result)
# from q t1 LEFT OUTER JOIN test.TweetItems_c t on t.row_id=t1.row_id where t1.result select value t;

# %%
a.head(2)
# Out:
#         contributors  coordinates          created_at display_text_range  \
# row_id
# 2                NaN          NaN 2018-02-08 05:18:41           [0, 140]
# 3                NaN          NaN 2018-02-08 05:18:41          [17, 140]
#
#                                                  entities  \
# row_id
# 2       {'hashtags': [{'text': 'POTUS', 'indices': [66...
# 3       {'hashtags': [], 'urls': [{'url': 'https://t.c...
#
#                                            extended_tweet  favorite_count  \
# row_id
# 2       {'full_text': 'CNN - INTERNATIONAL . THE LEAST...               0
# 3       {'full_text': '@realDonaldTrump The Russian As...               0
#
#         favorited filter_level  geo                  ...                   \
# row_id                                               ...
# 2           False          low  NaN                  ...
# 3           False          low  NaN                  ...
#
#         quoted_status_id_str  reply_count retweet_count  retweeted  \
# row_id
# 2               9.561978e+17            0             0      False
# 3                        NaN            0             0      False
#
#                                                    source  \
# row_id
# 2       <a href="http://twitter.com" rel="nofollow">Tw...
# 3       <a href="http://twitter.com/download/android" ...
#
#                                                      text  \
# row_id
# 2       CNN - INTERNATIONAL . THE LEAST  TRUSTED  NAME...
# 3       @realDonaldTrump The Russian Asset Donald Trum...
#
#                   timestamp_ms  truncated  \
# row_id
# 2      2018-02-08 05:18:41.713       True
# 3      2018-02-08 05:18:41.773       True
#
#                                                      user  \
# row_id
# 2       {'id': 882677034429710336, 'id_str': '88267703...
# 3       {'id': 958747420904497153, 'id_str': '95874742...
#
#                                         uuid
# row_id
# 2       5517ec1b-34f9-1e47-36bd-f78b48e6743b
# 3       5517ec1b-34f9-1e47-36bd-f78b48e6743c
#
# [2 rows x 34 columns]

# %%
b = df[(df['truncated'] == True) & (df['favorited'] == False)]
b.head(2)
# Out:
#         contributors coordinates          created_at display_text_range  \
# row_id
# 2                NaN        None 2018-02-08 05:18:41           [0, 140]
# 3                NaN        None 2018-02-08 05:18:41          [17, 140]
#
#                                                  entities extended_entities  \
# row_id
# 2       {'hashtags': [{'text': 'POTUS', 'indices': [66...               NaN
# 3       {'hashtags': [], 'urls': [{'url': 'https://t.c...               NaN
#
#                                            extended_tweet  favorite_count  \
# row_id
# 2       {'full_text': 'CNN - INTERNATIONAL . THE LEAST...               0
# 3       {'full_text': '@realDonaldTrump The Russian As...               0
#
#         favorited filter_level          ...          retweet_count  retweeted  \
# row_id                                  ...
# 2           False          low          ...                      0      False
# 3           False          low          ...                      0      False
#
#         retweeted_status                                             source  \
# row_id
# 2                    NaN  <a href="http://twitter.com" rel="nofollow">Tw...
# 3                    NaN  <a href="http://twitter.com/download/android" ...
#
#                                                      text  \
# row_id
# 2       CNN - INTERNATIONAL . THE LEAST  TRUSTED  NAME...
# 3       @realDonaldTrump The Russian Asset Donald Trum...
#
#                   timestamp_ms  truncated  \
# row_id
# 2      2018-02-08 05:18:41.713       True
# 3      2018-02-08 05:18:41.773       True
#
#                                                      user  \
# row_id
# 2       {'id': 882677034429710336, 'id_str': '88267703...
# 3       {'id': 958747420904497153, 'id_str': '95874742...
#
#                                         uuid withheld_in_countries
# row_id
# 2       5517ec1b-34f9-1e47-36bd-f78b48e6743b                   NaN
# 3       5517ec1b-34f9-1e47-36bd-f78b48e6743c                   NaN
#
# [2 rows x 37 columns]

# %%
df_a = a.collect()
print('AFrame cnt: %d' % len(df_a))
print('DataFrame cnt: %d' % len(b))
# Out:
# AFrame cnt: 564
# DataFrame cnt: 564

# %%
df.head()
# Out:
#         contributors coordinates          created_at display_text_range  \
# row_id
# 0                NaN        None 2018-02-08 05:18:41                NaN
# 1                NaN        None 2018-02-08 05:18:41                NaN
# 2                NaN        None 2018-02-08 05:18:41           [0, 140]
# 3                NaN        None 2018-02-08 05:18:41          [17, 140]
# 4                NaN        None 2018-02-08 05:18:41                NaN
#
#                                                  entities  \
# row_id
# 0       {'hashtags': [], 'urls': [], 'user_mentions': ...
# 1       {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2       {'hashtags': [{'text': 'POTUS', 'indices': [66...
# 3       {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 4       {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                         extended_entities  \
# row_id
# 0       {'media': [{'id': 961400756740923392, 'id_str'...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
#                                            extended_tweet  favorite_count  \
# row_id
# 0                                                     NaN               0
# 1                                                     NaN               0
# 2       {'full_text': 'CNN - INTERNATIONAL . THE LEAST...               0
# 3       {'full_text': '@realDonaldTrump The Russian As...               0
# 4                                                     NaN               0
#
#         favorited filter_level          ...          retweet_count  retweeted  \
# row_id                                  ...
# 0           False          low          ...                      0      False
# 1           False          low          ...                      0      False
# 2           False          low          ...                      0      False
# 3           False          low          ...                      0      False
# 4           False          low          ...                      0      False
#
#                                          retweeted_status  \
# row_id
# 0       {'created_at': 'Thu Feb 08 00:46:19 +0000 2018...
# 1       {'created_at': 'Wed Feb 07 22:54:04 +0000 2018...
# 2                                                     NaN
# 3                                                     NaN
# 4       {'created_at': 'Wed Feb 07 15:48:03 +0000 2018...
#
#                                                    source  \
# row_id
# 0       <a href="http://twitter.com" rel="nofollow">Tw...
# 1       <a href="http://twitter.com/download/iphone" r...
# 2       <a href="http://twitter.com" rel="nofollow">Tw...
# 3       <a href="http://twitter.com/download/android" ...
# 4       <a href="http://twitter.com/download/iphone" r...
#
#                                                      text  \
# row_id
# 0       RT @MicahGrimes: 2 iconic photos. 1 year. Only...
# 1       RT @EdKrassen: Nancy Pelosi has more Enerygy a...
# 2       CNN - INTERNATIONAL . THE LEAST  TRUSTED  NAME...
# 3       @realDonaldTrump The Russian Asset Donald Trum...
# 4       RT @nowthisnews: This Trump supporter used the...
#
#                   timestamp_ms  truncated  \
# row_id
# 0      2018-02-08 05:18:41.604      False
# 1      2018-02-08 05:18:41.705      False
# 2      2018-02-08 05:18:41.713       True
# 3      2018-02-08 05:18:41.773       True
# 4      2018-02-08 05:18:41.802      False
#
#                                                      user  \
# row_id
# 0       {'id': 320000200, 'id_str': '320000200', 'name...
# 1       {'id': 50667682, 'id_str': '50667682', 'name':...
# 2       {'id': 882677034429710336, 'id_str': '88267703...
# 3       {'id': 958747420904497153, 'id_str': '95874742...
# 4       {'id': 749752742, 'id_str': '749752742', 'name...
#
#                                         uuid withheld_in_countries
# row_id
# 0       5517ec1b-34f9-1e47-36bd-f78b48e6743a                   NaN
# 1       5517ec1b-34f9-1e47-36bd-f78b48e6743d                   NaN
# 2       5517ec1b-34f9-1e47-36bd-f78b48e6743b                   NaN
# 3       5517ec1b-34f9-1e47-36bd-f78b48e6743c                   NaN
# 4       5517ec1b-34f9-1e47-36bd-f78b48e6743e                   NaN
#
# [5 rows x 37 columns]

# %%
df = df.reset_index()

# %%
df2 = df

# %%
df3 = pd.concat([df,df2])

# %%
hdf = df.head()
hdf2 = df2.head()

# %%
hdf3 = pd.concat([hdf,hdf2])

# %%
hdf3
# Out:
#                    id  contributors coordinates          created_at  \
# 0  961689995286212609           NaN        None 2018-02-08 19:55:36
# 1  961689995734958080           NaN        None 2018-02-08 19:55:36
# 2  961689995965845506           NaN        None 2018-02-08 19:55:37
# 3  961689995793887232           NaN        None 2018-02-08 19:55:36
# 4  961689996557131776           NaN        None 2018-02-08 19:55:37
# 0  961689995286212609           NaN        None 2018-02-08 19:55:36
# 1  961689995734958080           NaN        None 2018-02-08 19:55:36
# 2  961689995965845506           NaN        None 2018-02-08 19:55:37
# 3  961689995793887232           NaN        None 2018-02-08 19:55:36
# 4  961689996557131776           NaN        None 2018-02-08 19:55:37
#
#   display_text_range                                           entities  \
# 0                NaN  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 1                NaN  {'hashtags': [{'text': 'RemoveNunes', 'indices...
# 2                NaN  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 3                NaN  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 4                NaN  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 0                NaN  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 1                NaN  {'hashtags': [{'text': 'RemoveNunes', 'indices...
# 2                NaN  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 3                NaN  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 4                NaN  {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#   extended_entities extended_tweet  favorite_count  favorited  \
# 0               NaN            NaN               0      False
# 1               NaN            NaN               0      False
# 2               NaN            NaN               0      False
# 3               NaN            NaN               0      False
# 4               NaN            NaN               0      False
# 0               NaN            NaN               0      False
# 1               NaN            NaN               0      False
# 2               NaN            NaN               0      False
# 3               NaN            NaN               0      False
# 4               NaN            NaN               0      False
#
#            ...          retweet_count retweeted  \
# 0          ...                      0     False
# 1          ...                      0     False
# 2          ...                      0     False
# 3          ...                      0     False
# 4          ...                      0     False
# 0          ...                      0     False
# 1          ...                      0     False
# 2          ...                      0     False
# 3          ...                      0     False
# 4          ...                      0     False
#
#                                     retweeted_status  \
# 0  {'created_at': 'Thu Feb 08 19:43:09 +0000 2018...
# 1  {'created_at': 'Thu Feb 08 14:50:34 +0000 2018...
# 2  {'created_at': 'Thu Feb 08 12:27:12 +0000 2018...
# 3  {'created_at': 'Thu Feb 08 19:54:15 +0000 2018...
# 4  {'created_at': 'Thu Feb 08 02:53:49 +0000 2018...
# 0  {'created_at': 'Thu Feb 08 19:43:09 +0000 2018...
# 1  {'created_at': 'Thu Feb 08 14:50:34 +0000 2018...
# 2  {'created_at': 'Thu Feb 08 12:27:12 +0000 2018...
# 3  {'created_at': 'Thu Feb 08 19:54:15 +0000 2018...
# 4  {'created_at': 'Thu Feb 08 02:53:49 +0000 2018...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com" rel="nofollow">Tw...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com" rel="nofollow">Tw...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                                 text            timestamp_ms  \
# 0  RT @Innrdreams: Right, GOP and Cabinet are com... 2018-02-08 19:55:36.869
# 1  RT @SaysHummingbird: Every single person who r... 2018-02-08 19:55:36.976
# 2  RT @BillKristol: The party of Lincoln today: B... 2018-02-08 19:55:37.031
# 3  RT @RawStory: These 14 Trump tweets perfectly ... 2018-02-08 19:55:36.990
# 4  RT @david_j_roth: It's weird how every single ... 2018-02-08 19:55:37.172
# 0  RT @Innrdreams: Right, GOP and Cabinet are com... 2018-02-08 19:55:36.869
# 1  RT @SaysHummingbird: Every single person who r... 2018-02-08 19:55:36.976
# 2  RT @BillKristol: The party of Lincoln today: B... 2018-02-08 19:55:37.031
# 3  RT @RawStory: These 14 Trump tweets perfectly ... 2018-02-08 19:55:36.990
# 4  RT @david_j_roth: It's weird how every single ... 2018-02-08 19:55:37.172
#
#    truncated                                               user  \
# 0      False  {'id': 302062283, 'id_str': '302062283', 'name...
# 1      False  {'id': 56721343, 'id_str': '56721343', 'name':...
# 2      False  {'id': 34756964, 'id_str': '34756964', 'name':...
# 3      False  {'id': 230485548, 'id_str': '230485548', 'name...
# 4      False  {'id': 15338832, 'id_str': '15338832', 'name':...
# 0      False  {'id': 302062283, 'id_str': '302062283', 'name...
# 1      False  {'id': 56721343, 'id_str': '56721343', 'name':...
# 2      False  {'id': 34756964, 'id_str': '34756964', 'name':...
# 3      False  {'id': 230485548, 'id_str': '230485548', 'name...
# 4      False  {'id': 15338832, 'id_str': '15338832', 'name':...
#
#                                    uuid withheld_in_countries
# 0  2fe6a60f-0210-01fe-b2ee-4d82a220c094                   NaN
# 1  2fe6a60f-0210-01fe-b2ee-4d82a220c095                   NaN
# 2  2fe6a60f-0210-01fe-b2ee-4d82a220c096                   NaN
# 3  2fe6a60f-0210-01fe-b2ee-4d82a220c097                   NaN
# 4  2fe6a60f-0210-01fe-b2ee-4d82a220c098                   NaN
# 0  2fe6a60f-0210-01fe-b2ee-4d82a220c094                   NaN
# 1  2fe6a60f-0210-01fe-b2ee-4d82a220c095                   NaN
# 2  2fe6a60f-0210-01fe-b2ee-4d82a220c096                   NaN
# 3  2fe6a60f-0210-01fe-b2ee-4d82a220c097                   NaN
# 4  2fe6a60f-0210-01fe-b2ee-4d82a220c098                   NaN
#
# [10 rows x 37 columns]

# %%
hdf3.loc[[0]]

# %%
hdf3[2:3]

# %%
hdf3_copy = hdf3

# %%
hdf3_copy

# %%
hdf3.join(hdf3_copy, rsuffix='copy')
